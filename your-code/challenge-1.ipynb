# %% [markdown]
# ## Before you start :
#    - These exercises are related to the Exploratory data analysis using matplotlib and seaborn.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - The datasets for Challenge 2 and 3 are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
# import libraries here
import numpy as np

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Define data.

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x,y) and (x,z) on the axes.
#
# #### There are 2 ways of doing this. Do in both ways.
#
# *Hint: Check out the `nrows`, `ncols`, and `index` arguments of [subplots](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html)*
#
# #### Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# your code here-1st way (call `subplots` twice using the `index` parameter)
fig, [ax1, ax2] = plt.subplots(1,2)

ax1.plot(x, y)
ax2.plot(x, z)

plt.show();

# %%
# your code here-2st way (call `subplots` only once not using the `index` parameter)
plt.plot(x, y, label = 'x-y')
plt.plot(x, z, label = 'x-z')

plt.show();

# %% [markdown]
# #### Augmenting your previous code, resize your previous plot.
#
# *Hint: Add the `figsize` argument in `plt.subplots()`*

# %%
# your code here
fig, [ax1, ax2] = plt.subplots(1,2, figsize = (20, 10))

ax1.plot(x, y)
ax2.plot(x, z)

plt.show();

# %% [markdown]
# #### Augmenting your previous code, label your axes.
#
# *Hint: call `set_xlabel` and `set_ylabel`*

# %%
# your code here

fig, [ax1, ax2] = plt.subplots(1,2, figsize = (20, 10))

ax1.plot(x, y)
ax2.plot(x, z)

ax1.set_xlabel('Xs', fontsize = 23)
ax1.set_ylabel('Ys', fontsize = 23)

ax2.set_xlabel('Xs', fontsize = 23)
ax2.set_ylabel('Zs', fontsize = 23)

plt.show();

# %% [markdown]
# #### Plot both `y=x^2` and `y=exp(x)` in the same plot using normal and logarithmic scale.
#
# *Hint: Use `set_xscale` and `set_yscale`*

# %%
# your code here

plt.plot(x, y, x, y)
plt.xscale('linear')
plt.title('linear') 

plt.yscale('log')
plt.title('log')

plt.show();
# Out:
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\ticker.py:2456: RuntimeWarning: divide by zero encountered in double_scalars
#   vmin = np.log10(vmin / (1 - vmin))
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\ticker.py:2457: RuntimeWarning: divide by zero encountered in log10
#   vmax = np.log10(vmax / (1 - vmax))
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1081: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1091: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1081: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1091: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1081: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1091: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# posx and posy should be finite values
# posx and posy should be finite values
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1081: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1091: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1081: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1091: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1081: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1091: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1081: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1091: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1081: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1091: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1081: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1091: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1081: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1091: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1081: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1091: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1081: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1091: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1081: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1091: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1081: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1091: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1081: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1091: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1081: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1091: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1081: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1091: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1081: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1091: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1081: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1091: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1081: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1091: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1081: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1091: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1081: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1091: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1081: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1091: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1081: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1091: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1081: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1091: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1081: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1091: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1081: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1091: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# posx and posy should be finite values
# posx and posy should be finite values
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1081: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# C:\Users\lponc\Anaconda3\lib\site-packages\matplotlib\axis.py:1091: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "

# %% [markdown]
# #### In the vehicles data set that you have downloaded, use the vehicles.csv file. In this exercise we will conduct some exploratory data analysis using one plot each of scatter plot, box plot, histogram, and bar chart.

# %% [markdown]
# Scatter Plot
#
# Please provide a scatter plot between "Combined MPG" as X variable and
# "Highway MPG" as Y variable

# %%
# your code here
vehicles = pd.read_csv('vehicles.csv')

# %%
plt.scatter('Combined MPG', 'Highway MPG', data = vehicles);

# %% [markdown]
# Box Whisker Plot
#
# Please provide a box plot of the variable "CO2 Emission Grams/mile"

# %%
# your code here
vehicles.boxplot(column = 'CO2 Emission Grams/Mile');

# %% [markdown]
# Histogram
#
# Please provide a histogram of the Fuel Barrels/Year

# %%
# your code here
vehicles['Fuel Barrels/Year'].hist(bins = 50);

# %% [markdown]
# Bar Chart
#
# Please provide a bar chart of the Fuel Type on the X axis and "City MPG" on the Y axis

# %%
# your code here
ax = sns.barplot('Fuel Type', 'City MPG', data = vehicles)
ax.set_xticklabels(ax.get_xticklabels(), rotation = 90);
